# %%
import dataread
import data_header

samples = dataread.read_samples(100)
samples = data_header.count_header_min_floor(samples, 5)
data_header.plot_header_count(samples, 20)

# %%
import dataread
import data_header

samples = dataread.read_samples(1000)
samples = data_header.count_header_min_floor(samples, 5)
data_header.plot_header_count(samples, 20)

# %%
import dataread
import dataheader

samples = dataread.read_samples(50000)
samples = dataheader.count_header_min_floor(samples, 5)
dataheader.plot_header_count(samples, 20)
